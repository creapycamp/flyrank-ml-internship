# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/creapycamp/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# # 1 My Lane as an ML Task
#
# I selected **Lane 2: Refresh / Content Opportunity Scoring**.
#
# This is primarily a **scoring and ranking** problem. The objective is to rank content pages according to their priority for review and refresh. The output is a ranked list that helps reviewers decide which pages to investigate first.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# # 2 Target or Proxy
#
# The starter dataset uses the proxy target:
#
# is_declining_label = (trend_direction == "down")
#
# This proxy identifies pages that are currently showing signs of decline. In a future version using the warehouse data, the target could be a future decline or recovery measured over a later time window.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# #3 Success Metric
#
# The primary success metric is **Precision@K**, because reviewers can only inspect a limited number of pages.
#
# Additional evaluation metrics include:
#
# - Average Precision
# - ROC-AUC
# - Recall
#
# Precision@K best reflects the real-world decision of selecting the most valuable pages for review.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# #4 Unit of Analysis
#
# One row represents **one content page** together with its search and engagement measurements from the starter dataset.
#
# Each row contains information such as impressions, clicks, CTR, sessions, content age, freshness, and trend direction.

# %%
# !git clone https://github.com/creapycamp/flyrank-ml-internship.git
# %cd flyrank-ml-internship

import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print(df.head())
print(df.shape)
# Out:
# Cloning into 'flyrank-ml-internship'...
# remote: Enumerating objects: 144, done.
# remote: Counting objects: 100% (144/144), done.
# remote: Compressing objects: 100% (100/100), done.
# remote: Total 144 (delta 55), reused 86 (delta 28), pack-reused 0 (from 0)
# Receiving objects: 100% (144/144), 1.84 MiB | 14.75 MiB/s, done.
# Resolving deltas: 100% (55/55), done.
# /content/flyrank-ml-internship
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# ...

# %%
df["target"] = (df["trend_direction"] == "down").astype(int)

df[["content_id", "trend_direction", "target"]].head()
# Out:
#              content_id trend_direction  target
# 0  content_304f48230142            down       1
# 1  content_a1fb4e703a9e            down       1
# 2  content_9aa793d4d895            down       1
# 3  content_331d6c4de07b          stable       0
# 4  content_d99b7a2d90ca            down       1

# %% [markdown]
# #5 Why ML Beats a Fixed Rule
#
# A fixed rule applies the same conditions to every page regardless of context.
#
# Machine learning can combine multiple signals such as impressions, clicks, CTR, content age, engagement, and freshness to identify complex patterns that simple rules may miss.
#
# The resulting ranking provides a more flexible and evidence-based way to prioritize pages for review.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
