# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/creapycamp/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# I selected **Lane 2: Refresh / Content Opportunity Scoring**.
#
# This lane focuses on identifying pages that should be reviewed first for content refresh, improvement, monitoring, or optimization. I selected this lane because it provides actionable recommendations using search and engagement data.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import os

print(os.path.exists("data/raw/content_refresh_anonymized.csv"))
# Out:
# True

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# !git clone https://github.com/creapycamp/flyrank-ml-internship.git
# %cd flyrank-ml-internship
# Out:
# Cloning into 'flyrank-ml-internship'...
# remote: Enumerating objects: 129, done.
# remote: Counting objects: 100% (129/129), done.
# remote: Compressing objects: 100% (85/85), done.
# remote: Total 129 (delta 44), reused 87 (delta 28), pack-reused 0 (from 0)
# Receiving objects: 100% (129/129), 1.84 MiB | 10.47 MiB/s, done.
# Resolving deltas: 100% (44/44), done.
# /content/flyrank-ml-internship/flyrank-ml-internship

# %% [markdown]
# ## Research Question
#
# Which pages should be reviewed first for content refresh based on search performance and engagement signals?
#
# ### Decision
#
# Determine which pages deserve priority for review.
#
# ### Action
#
# Review and improve the selected pages by updating content, metadata, or structure.
#
# ### Cost of a Wrong Recommendation
#
# If the wrong pages are prioritized, time and effort may be wasted while important pages continue losing visibility and traffic.
#
# ### Why Data and Machine Learning Help
#
# Historical search and engagement signals provide evidence about page performance. Data-driven ranking can prioritize pages more consistently than manual judgment alone.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Rows:", len(df))
print("Columns:", len(df.columns))
print("Unique clients:", df["client_id"].nunique())
print("Unique pages:", df["content_id"].nunique())
print("Average CTR:", df["ctr"].mean())
# Out:
# Rows: 30000
# Columns: 44
# Unique clients: 32
# Unique pages: 30000
# Average CTR: 0.5107333333333334

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# ## Careful Words
#
# This analysis identifies pages that appear to deserve review based on observed search and engagement signals.
#
# It does not prove that refreshing a page will increase traffic or rankings.
#
# The recommendations should be treated as decision support rather than guaranteed outcomes.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
